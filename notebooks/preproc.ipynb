# %% [markdown]
# Notebook purpose
#
# - Sense-check and explore calculated account balances

# %%
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sys.path.append('/Users/fgu/dev/projects/entropy')
from entropy import config
import entropy.helpers.aws as aws
import entropy.data.cleaners as cl
import entropy.data.creators as cr
import entropy.figures.figures as figs

sns.set_style('whitegrid')
pd.set_option('display.max_rows', 120)
pd.set_option('display.max_columns', 120)
pd.set_option('max_colwidth', None)
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
SAMPLE = '777'
fp = f'~/tmp/entropy_{SAMPLE}.parquet'
df = aws.read_parquet(fp)
df.head(3)
# Out:
#    Transaction Reference  User Reference User Registration Date  \
# 0                 688293             777             2011-07-20
# 1                 688291             777             2011-07-20
# 2                 688290             777             2011-07-20
#
#    Year of Birth Salary Range Postcode       LSOA       MSOA Derived Gender  \
# 0         1969.0   20K to 30K    WA1 4  E01012553  E02002603              M
# 1         1969.0   20K to 30K    WA1 4  E01012553  E02002603              M
# 2         1969.0   20K to 30K    WA1 4  E01012553  E02002603              M
#
#   Transaction Date  Account Reference Provider Group Name Account Type  \
# 0       2012-01-25             262916        NatWest Bank      Current
# 1       2012-01-25             262916        NatWest Bank      Current
# 2       2012-01-25             262916        NatWest Bank      Current
#
#    Latest Recorded Balance  \
# 0               364.220001
# 1               364.220001
# 2               364.220001
#
#                                     Transaction Description Credit Debit  \
# 0               9572 24jan12 , tcs bowdon , bowdon gb - pos        Debit
# 1                                     warrington b.c. - d/d        Debit
# 2  9572 24jan12 , apple itunes store, gbp , london gb - pos        Debit
#
#       Amount User Precedence Tag Name Manual Tag Name  \
# 0  25.030001                   No Tag          No Tag
# 1  26.000000           Gym Membership  Gym Membership
# 2   6.970000               Mobile app          No Tag
#
#       Auto Purpose Tag Name Merchant Name Merchant Business Line  \
# 0                    No Tag   No Merchant       Unknown Merchant
# 1                    No Tag   No Merchant       Unknown Merchant
# 2  Entertainment, TV, Media         Apple                  Apple
#
#   Account Created Date Account Last Refreshed Data Warehouse Date Created  \
# 0           2011-07-20    2020-07-21 20:32:00                  2014-07-18
# 1           2011-07-20    2020-07-21 20:32:00                  2014-07-18
# 2           2011-07-20    2020-07-21 20:32:00                  2014-07-18
#
#   Data Warehouse Date Last Updated Transaction Updated Flag
# 0                       2017-10-24                        U
# 1                       2017-10-23                        U
# 2                       2017-08-15                        U
