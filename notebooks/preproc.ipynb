# %% [markdown]
# Notebook purpose
#
# - Sense-check and explore calculated account balances

# %%
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sys.path.append('/Users/fgu/dev/projects/entropy')
from entropy import config
import entropy.helpers.aws as aws
import entropy.data.cleaners as cl
import entropy.data.creators as cr
import entropy.figures.figures as figs

sns.set_style('whitegrid')
pd.set_option('display.max_rows', 120)
pd.set_option('display.max_columns', 120)
pd.set_option('max_colwidth', None)
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
SAMPLE = '777'
fp = f'~/tmp/entropy/entropy_{SAMPLE}.parquet'
df = aws.read_parquet(fp)
df.head(3)
# Out:
#        id       date  user_id  amount  \
# 0  688261 2012-01-03      777  400.00
# 1  688264 2012-01-03      777   10.27
# 2  688263 2012-01-03      777    6.68
#
#                                                  desc   merchant  tag_group  \
# 0                                          mdbremoved        NaN  transfers
# 1  9572 30dec 11 mcdonalds restaurant winwick road gb  mcdonalds      spend
# 2       9572 31dec 11 tesco stores 3345 warrington gb      tesco      spend
#
#          tag  user_female user_postcode user_registration_date  \
# 0  transfers          0.0         wa1 4             2011-07-20
# 1   services          0.0         wa1 4             2011-07-20
# 2  household          0.0         wa1 4             2011-07-20
#
#   user_salary_range  user_yob account_created  account_id  \
# 0        20k to 30k    1969.0      2011-07-20      262916
# 1        20k to 30k    1969.0      2011-07-20      262916
# 2        20k to 30k    1969.0      2011-07-20      262916
#
# ...

# %% [markdown]
# ## Balance calc

# %%
k = df[df.account_id.isin([262916, 262920])].drop(columns='balance').set_index('date').resample('w').sum()
k.index.get_loc(pd.Timestamp('2012-01-1 00:00:00'), method='bfill')
# Out:
# 0

# %%
d.index.get_loc
# Out:
#              id       date  user_id  amount  \
# 0        688261 2012-01-03      777  400.00
# 1        688264 2012-01-03      777   10.27
# 2        688263 2012-01-03      777    6.68
# 3        688265 2012-01-03      777   12.00
# 4        688262 2012-01-03      777    3.03
# ...         ...        ...      ...     ...
# 7113  799453817 2020-07-17      777    4.99
# 7114  800150185 2020-07-20      777    1.99
# 7115  800150186 2020-07-20      777    9.99
# 7116  800150187 2020-07-20      777   19.99
# 7117  800150184 2020-07-20      777   24.98
#
#                                                     desc   merchant  \
# 0                                             mdbremoved        NaN
# 1     9572 30dec 11 mcdonalds restaurant winwick road gb  mcdonalds
# 2          9572 31dec 11 tesco stores 3345 warrington gb      tesco
# 3          9572 31dec 11 tesco stores 3345 warrington gb      tesco
# 4                                               aviva pa      aviva
# ...

# %%
d = df[df.account_id.isin([262916, 262920])].drop(columns='balance')

# %%
cr.balances(d)
# Out:
# date
# 2012-01-03    -431.980011
# 2012-01-04    -449.470001
# 2012-01-05    -449.470001
# 2012-01-06    -491.119995
# 2012-01-07    -491.119995
#                  ...
# 2020-07-16    1537.176392
# 2020-07-17    1532.186401
# 2020-07-18    1532.186401
# 2020-07-19    1532.186401
# 2020-07-20    1475.236450
# Freq: D, Name: amount, Length: 3122, dtype: float32
# date
# 2014-01-25     -12.470000
# 2014-01-26     -55.060001
# 2014-01-27    -110.900002
# 2014-01-28    -110.900002
# 2014-01-29    -110.900002
#                  ...
# 2016-07-10    3552.549561
# 2016-07-11    3362.599609
# 2016-07-12    3245.599609
# 2016-07-13    3245.599609
# 2016-07-14    3247.139648
# Freq: D, Name: amount, Length: 902, dtype: float32
#    account_id     0
# 0      262916  3121
# 1      262920   901
