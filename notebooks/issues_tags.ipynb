# %% [markdown]
# Notebook purpose
#
# - Document problems in MBD raw data

# %%
import os
import sys

import numpy as np
import pandas as pd
import seaborn as sns

sys.path.append('/Users/fgu/dev/projects/entropy')
import entropy.helpers.aws as aws
import entropy.data.cleaners as cl

sns.set_style('whitegrid')
pd.set_option('display.max_rows', 120)
pd.set_option('display.max_columns', 120)
pd.set_option('max_colwidth', None)
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

# %%
m = aws.S3BucketManager('3di-project-entropy')
m.list()
# Out:
# ['3di-project-entropy/entropy_000.parquet',
#  '3di-project-entropy/entropy_777.parquet',
#  '3di-project-entropy/entropy_X77.parquet']

# %% [markdown]
# ## Debits as income

# %% [markdown]
# Classifying income following hacioglu2020distributional results in a substantial number of debits classified as income. They all belong to one of three auto tags, which we'll investigate below.

# %%
SAMPLE = 'X77'
fp = f'~/tmp/entropy_{SAMPLE}.parquet'
df = aws.read_parquet(fp)

# %%
mask = df.tag_group.eq('income') & df.amount.gt(0)
d = df[mask]
d.amount.describe()
# Out:
# count     1582.000000
# mean       311.669220
# std       1604.520386
# min          0.100000
# 25%         10.410000
# 50%         25.000000
# 75%        125.180000
# max      29000.000000
# Name: amount, dtype: float64

# %%
d.tag_auto.value_counts()[:5]
# Out:
# pension or investments    1379
# interest income            177
# unsecured loan funds        26
# pet - everyday or food       0
# payday loan                  0
# Name: tag_auto, dtype: int64

# %% [markdown]
# ## Pension or investments

# %% [markdown]
# ### Problem
#
# This key contains both pension income (when amount is negative) and -- mostly -- pension contributions (when amount is positive)

# %%
mask = df.tag_auto.eq('pension or investments') & df.amount.lt(0)
d = df[mask]
print(d.shape)
d.head(2)
# Out:
# (12, 31)
#                id       date  user_id      amount                desc  \
# 115099  164193570 2016-10-11    65677 -111.309998  john lewis pension
# 115146  169774214 2016-11-10    65677 -111.510002  john lewis pension
#
#           merchant tag_group       tag user_female user_postcode  \
# 115099  john lewis    income  pensions       False         ng9 6
# 115146  john lewis    income  pensions       False         ng9 6
#
#        user_registration_date user_salary_range  user_yob account_created  \
# 115099             2014-06-02               NaN    1959.0      2016-10-09
# 115146             2014-06-02               NaN    1959.0      2016-10-09
#
#         account_id account_last_refreshed          account_provider  \
# 115099      612941    2020-03-11 11:12:00  halifax personal banking
# 115146      612941    2020-03-11 11:12:00  halifax personal banking
#
#        account_type data_warehouse_date_created  \
# 115099      current                  2016-10-12
# 115146      current                  2016-11-11
#
#        data_warehouse_date_last_updated  debit  latest_balance  \
# 115099                       2018-04-02  False    20667.589844
# 115146                       2018-04-02  False    20667.589844
#
#        merchant_business_line                tag_auto tag_manual  \
# 115099       john lewis other  pension or investments        NaN
# 115146       john lewis other  pension or investments        NaN
#
#                    tag_up updated_flag      ym       balance        income  \
# 115099       work pension            u  201610  15557.872070  57253.828125
# 115146  refunded purchase            u  201611  15236.822266  57253.828125
#
#         savings
# 115099    False
# 115146    False

# %%
mask = df.tag_auto.eq('pension or investments') & df.amount.gt(0)
d = df[mask]
print(d.shape)
d.head(2)
# Out:
# (1379, 31)
#             id       date  user_id  amount                       desc  \
# 15248  3407594 2013-01-28     3277   500.0  www.hl.co.uk <mdbremoved>
# 15358  4112473 2013-03-07     3277    50.0         hlam regular savin
#
#                   merchant tag_group       tag user_female user_postcode  \
# 15248  hargreaves lansdown    income  pensions        True        sw19 1
# 15358  hargreaves lansdown    income  pensions        True        sw19 1
#
#       user_registration_date user_salary_range  user_yob account_created  \
# 15248             2012-09-26               NaN    1987.0      2012-09-26
# 15358             2012-09-26               NaN    1987.0      2012-09-26
#
#        account_id account_last_refreshed account_provider account_type  \
# 15248      253764             2015-03-16     first direct      current
# 15358      253764             2015-03-16     first direct      current
#
#       data_warehouse_date_created data_warehouse_date_last_updated  debit  \
# 15248                  2014-07-18                       2017-12-04   True
# 15358                  2014-07-18                       2020-03-17   True
#
#        latest_balance merchant_business_line                tag_auto  \
# 15248             NaN    hargreaves lansdown  pension or investments
# 15358             NaN    hargreaves lansdown  pension or investments
#
#       tag_manual              tag_up updated_flag      ym  balance  \
# 15248        NaN                 NaN            u  201301      NaN
# 15358        NaN  investment - other            u  201303      NaN
#
#              income  savings
# 15248  32259.191406    False
# 15358  32259.191406    False

# %% [markdown]
# ### Solution

# %% [markdown]
# Classify debits and credits separately

# %% [markdown]
# ## Interest income

# %% [markdown]
# ### Problem

# %% [markdown]
# Most txns labelled as interest income clearly are

# %%
mask = df.tag_auto.eq('interest income') & df.amount.lt(0)
d = df[mask]
print(d.shape)
d.head(2)
# Out:
# (5122, 31)
#             id       date  user_id  amount  \
# 1732  43934679 2014-09-29      777   -1.40
# 3044  98389865 2015-09-29      777   -1.34
#
#                                                           desc merchant  \
# 1732  interest added - gross interest £1.75 tax deducted £0.35      NaN
# 3044  interest added - gross interest £1.68 tax deducted £0.34      NaN
#
#      tag_group           tag user_female user_postcode user_registration_date  \
# 1732    income  other_income       False         wa1 4             2011-07-20
# 3044    income  other_income       False         wa1 4             2011-07-20
#
#      user_salary_range  user_yob account_created  account_id  \
# 1732        20k to 30k    1969.0      2014-11-19      262912
# 3044        20k to 30k    1969.0      2014-11-19      262912
#
#      account_last_refreshed account_provider account_type  \
# 1732    2016-07-24 15:29:00       nationwide      current
# 3044    2016-07-24 15:29:00       nationwide      current
#
#      data_warehouse_date_created data_warehouse_date_last_updated  debit  \
# 1732                  2014-11-19                       2017-08-13  False
# 3044                  2015-10-02                       2017-08-12  False
#
#       latest_balance merchant_business_line         tag_auto tag_manual  \
# 1732       43.450001       account provider  interest income        NaN
# 3044       43.450001       account provider  interest income        NaN
#
#                tag_up updated_flag      ym     balance        income  savings
# 1732  interest income            u  201409  842.109985  26204.169922    False
# 3044  interest income            u  201509   43.450012  27638.970703    False

# %% [markdown]
# Yet a small minority, those that are debits, are actually overdraft fees

# %%
mask = df.tag_auto.eq('interest income') & df.amount.gt(0)
d = df[mask]
print(d.shape)
d.head(2)
# Out:
# (177, 31)
#               id       date  user_id  amount                            desc  \
# 71235  806079392 2017-07-15    35177    1.99  overdraft interestto 23jun2017
# 71341  806079376 2017-08-14    35177    7.84  overdraft interestto 23jul2017
#
#       merchant tag_group           tag user_female user_postcode  \
# 71235      NaN    income  other_income       False        xxxx 0
# 71341      NaN    income  other_income       False        xxxx 0
#
#       user_registration_date user_salary_range  user_yob account_created  \
# 71235             2014-02-14        20k to 30k    1990.0      2017-05-25
# 71341             2014-02-14        20k to 30k    1990.0      2017-05-25
#
#        account_id account_last_refreshed account_provider account_type  \
# 71235      724235    2020-08-14 20:59:00             hsbc      current
# 71341      724235    2020-08-14 20:59:00             hsbc      current
#
#       data_warehouse_date_created data_warehouse_date_last_updated  debit  \
# 71235                  2020-08-12                       1900-01-01   True
# 71341                  2020-08-12                       1900-01-01   True
#
#        latest_balance merchant_business_line         tag_auto tag_manual  \
# 71235      844.299988       account provider  interest income        NaN
# 71341      844.299988       account provider  interest income        NaN
#
#                 tag_up updated_flag      ym      balance        income  \
# 71235  interest income            c  201707  1269.640869  26090.759766
# 71341  interest income            c  201708   805.120911  26090.759766
#
#        savings
# 71235    False
# 71341    False

# %%
d.desc.str[:18].value_counts(dropna=False)
# Out:
# overdraft interest    177
# Name: desc, dtype: int64

# %% [markdown]
# ### Solution

# %% [markdown]
# Classify debits and credits separately

# %% [markdown]
# ## Unsecured loan funds

# %% [markdown]
# Should loan funds be classified as income to start with?

# %% [markdown]
# ### Problem

# %% [markdown]
# How to classify loans (also payday loans in general?)

# %%
mask = df.tag_auto.eq('unsecured loan funds') & df.amount.lt(0)
d = df[mask]
print(d.shape)
d.head(2)
# Out:
# (413, 31)
#              id       date  user_id   amount          desc merchant tag_group  \
# 19575   2120049 2012-11-28     4277 -10000.0  <mdbremoved>      NaN    income
# 25170  20858977 2014-04-15    14577  -7500.0  <mdbremoved>      NaN    income
#
#                 tag user_female user_postcode user_registration_date  \
# 19575  other_income       False        kt15 2             2012-10-07
# 25170  other_income       False         pr2 6             2013-01-06
#
#       user_salary_range  user_yob account_created  account_id  \
# 19575               NaN    1959.0      2012-10-07      110411
# 25170               NaN    1984.0      2014-05-26      104213
#
#       account_last_refreshed account_provider account_type  \
# 19575    2014-02-17 11:02:00     first direct      current
# 25170    2015-01-04 00:00:00        santander      current
#
#       data_warehouse_date_created data_warehouse_date_last_updated  debit  \
# 19575                  2014-07-18                       2015-03-19  False
# 25170                  2014-07-18                       2015-03-19  False
#
#        latest_balance merchant_business_line              tag_auto tag_manual  \
# 19575    -1038.719971                    NaN  unsecured loan funds        NaN
# 25170             NaN                    NaN  unsecured loan funds        NaN
#
#                      tag_up updated_flag      ym     balance        income  \
# 19575                   NaN            u  201211  8315.09082  74063.592188
# 25170  unsecured loan funds            u  201404         NaN  37589.246652
#
#        savings
# 19575    False
# 25170    False

# %%
mask = df.tag_auto.eq('unsecured loan funds') & df.amount.gt(0)
d = df[mask]
print(d.shape)
d.head(2)
# Out:
# (26, 31)
#                id       date  user_id      amount  \
# 971778  603826282 2019-02-25   513377  186.020004
# 971936  604129805 2019-03-25   513377  186.020004
#
#                                                                           desc  \
# 971778  direct debit payment to aa loans ref xxxxxxxxxxxx0661, mandate no 0033
# 971936  direct debit payment to aa loans ref xxxxxxxxxxxx0661, mandate no 0033
#
#           merchant tag_group           tag user_female user_postcode  \
# 971778  aa finance    income  other_income        None         g61 4
# 971936  aa finance    income  other_income        None         g61 4
#
#        user_registration_date user_salary_range  user_yob account_created  \
# 971778             2019-05-24        20k to 30k    1977.0      2019-09-03
# 971936             2019-05-24        20k to 30k    1977.0      2019-09-03
#
#         account_id account_last_refreshed account_provider account_type  \
# 971778     1414589    2020-08-16 11:32:00        santander      current
# 971936     1414589    2020-08-16 11:32:00        santander      current
#
#        data_warehouse_date_created data_warehouse_date_last_updated  debit  \
# 971778                  2019-09-04                       1900-01-01   True
# 971936                  2019-09-04                       1900-01-01   True
#
#         latest_balance merchant_business_line              tag_auto  \
# 971778      261.730011             aa finance  unsecured loan funds
# 971936      261.730011             aa finance  unsecured loan funds
#
#        tag_manual                tag_up updated_flag      ym      balance  \
# 971778        NaN  unsecured loan funds            c  201902 -2556.750977
# 971936        NaN  unsecured loan funds            c  201903 -2566.330811
#
#               income  savings
# 971778  25555.388672    False
# 971936  25555.388672    False

# %% [markdown]
# ## Untagged transfers

# %%
df = pd.read_parquet('~/tmp/entropy_X77.parquet')

# %% [markdown]
# ### Problem
#
# There are txns that are clearly transfers but aren't tagged as such ('tranfsers' is only the most obvious strings, the same is true for others like 'xfer', 'trf').

# %%
untagged_tfrs = df[df.desc.str.contains('transfer') & df.tag.isna()]
untagged_tfrs.head()
# Out:
#             id       date  user_id  amount                        desc  \
# 1625  43934685 2014-08-31      777  -400.0  transfer from <mdbremoved>
# 1626  43934684 2014-08-31      777  -300.0  transfer from <mdbremoved>
# 1738  43934696 2014-09-30      777  -400.0  transfer from <mdbremoved>
# 1739  43934695 2014-09-30      777  -300.0  transfer from <mdbremoved>
# 1845  43934706 2014-11-02      777  -400.0  transfer from <mdbremoved>
#
#      merchant tag_group   tag user_female user_postcode  \
# 1625      NaN      None  None       False         wa1 4
# 1626      NaN      None  None       False         wa1 4
# 1738      NaN      None  None       False         wa1 4
# 1739      NaN      None  None       False         wa1 4
# 1845      NaN      None  None       False         wa1 4
#
#      user_registration_date user_salary_range  user_yob account_created  \
# 1625             2011-07-20        20k to 30k    1969.0      2014-11-19
# 1626             2011-07-20        20k to 30k    1969.0      2014-11-19
# 1738             2011-07-20        20k to 30k    1969.0      2014-11-19
# 1739             2011-07-20        20k to 30k    1969.0      2014-11-19
# 1845             2011-07-20        20k to 30k    1969.0      2014-11-19
#
#       account_id account_last_refreshed account_provider account_type  \
# 1625      262914    2016-07-24 15:29:00       nationwide      current
# 1626      262914    2016-07-24 15:29:00       nationwide      current
# 1738      262914    2016-07-24 15:29:00       nationwide      current
# 1739      262914    2016-07-24 15:29:00       nationwide      current
# 1845      262914    2016-07-24 15:29:00       nationwide      current
#
#      data_warehouse_date_created data_warehouse_date_last_updated  debit  \
# 1625                  2014-11-19                       2017-08-13  False
# 1626                  2014-11-19                       2017-08-13  False
# 1738                  2014-11-19                       2017-08-13  False
# 1739                  2014-11-19                       2017-08-13  False
# 1845                  2014-11-19                       2017-08-13  False
#
#       latest_balance merchant_business_line tag_auto tag_manual tag_up  \
# 1625     1637.530029                    NaN      NaN        NaN    NaN
# 1626     1637.530029                    NaN      NaN        NaN    NaN
# 1738     1637.530029                    NaN      NaN        NaN    NaN
# 1739     1637.530029                    NaN      NaN        NaN    NaN
# 1845     1637.530029                    NaN      NaN        NaN    NaN
#
#           ym      balance      income
# 1625  201408  2565.380371  158.399998
# 1626  201408  2565.380371  158.399998
# 1738  201409  3166.390381  158.399998
# 1739  201409  3166.390381  158.399998
# 1845  201411  3631.200439  158.399998

# %% [markdown]
# ### Questions for MDB
#
# - There are txns for which the above strings are part of the description and that are tagged as tranfsers, indicating that it's not simply that strings are missing from classification regex. Are there reasone the above aren't classified or is this a bug?

# %% [markdown]
# ### Solution

# %% [markdown]
# ## Auto purpose tag inconsistency
#
# Auto purpose tag should equal manual tag if manual tag is not missing and else equal Auto Purpose Tag. There are many cases where this is not the case.

# %% [markdown]
# ### Case 1: incorrectly empty user precedence tag

# %%
df = aws.s3read_parquet('s3://3di-data-mdb/raw/mdb_777.parquet')
df.head(1)
# Out:
#    Transaction Reference  User Reference User Registration Date  \
# 0                 688293             777             2011-07-20
#
#    Year of Birth Salary Range Postcode       LSOA       MSOA Derived Gender  \
# 0         1969.0   20K to 30K    WA1 4  E01012553  E02002603              M
#
#   Transaction Date  Account Reference Provider Group Name Account Type  \
# 0       2012-01-25             262916        NatWest Bank      Current
#
#    Latest Recorded Balance                      Transaction Description  \
# 0               364.220001  9572 24jan12 , tcs bowdon , bowdon gb - pos
#
#   Credit Debit     Amount User Precedence Tag Name Manual Tag Name  \
# 0        Debit  25.030001                   No Tag          No Tag
#
#   Auto Purpose Tag Name Merchant Name Merchant Business Line  \
# 0                No Tag   No Merchant       Unknown Merchant
#
#   Account Created Date Account Last Refreshed Data Warehouse Date Created  \
# 0           2011-07-20    2020-07-21 20:32:00                  2014-07-18
#
#   Data Warehouse Date Last Updated Transaction Updated Flag
# 0                       2017-10-24                        U

# %%
tag_names = ['User Precedence Tag Name', 'Manual Tag Name', 'Auto Purpose Tag Name']
tags = df[tag_names]

mask = ((tags['User Precedence Tag Name'] == 'No Tag')
        & ((tags['Auto Purpose Tag Name'] != 'No Tag') 
           | (tags['Manual Tag Name'] != 'No Tag')))
errors = tags[mask]
errors.head(3)
# Out:
#    User Precedence Tag Name Manual Tag Name Auto Purpose Tag Name
# 33                   No Tag          No Tag                  Cash
# 36                   No Tag          No Tag      Interest charges
# 37                   No Tag          No Tag       Lunch or Snacks

# %%
print(f'Tags are incorrect in {len(errors) / len(df):.1%} percent of observations.')
# Out:
# Tags are incorrect in 8.9% percent of observations.

# %% [markdown]
# ### Case 2: incorrectly empty manual and auto purpose tag

# %%
mask = ((tags['User Precedence Tag Name'] != 'No Tag')
        & (tags['Auto Purpose Tag Name'] == 'No Tag') 
        & (tags['Manual Tag Name'] == 'No Tag'))
errors = tags[mask]
errors.head(2)
# Out:
#     User Precedence Tag Name Manual Tag Name Auto Purpose Tag Name
# 507        Financial - other          No Tag                No Tag
# 590                    Water          No Tag                No Tag

# %%
print(f'Tags are incorrect in {len(errors) / len(df):.1%} percent of observations.')
# Out:
# Tags are incorrect in 0.4% percent of observations.

# %% [markdown]
# ### Correction

# %%
def correct_tag_up(df):
    """Set tag_up to tag_manual if tag_manual not missing else to tag_auto.
    
    This definition of tag_up is violated in two ways: sometimes tag_up is
    missing while one of the other two tags isn't, sometimes tag_up is
    not missing but both other tags are. In the latter case, we leave tag_up
    unchanged.
    """
    correct_up_value = df.tag_manual.fillna(df.tag_auto)
    df['tag_up'] = (df.tag_up.where(df.tag_up.notna(), correct_up_value))
    return df
